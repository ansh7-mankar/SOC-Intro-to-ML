# %% [markdown]
# # Python Libraries
#
# This notebook introduces:
# - NumPy
# - Pandas
# - Matplotlib
#
# You will also learn:
# - Reading CSV files
# - Basic data analysis
# - Data visualization
#
# Make sure the CSV files are in the same folder as this notebook.

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in C:\Users\ANSH\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\ANSH\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\ANSH\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\ANSH\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\ANSH\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\ANSH\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in C:\Users\ANSH\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in C:\Users\ANSH\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\ANSH\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\ANSH\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\ANSH\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. NumPy Basics
#
# NumPy is used for numerical computing and efficient array operations.

# %%
# Creating arrays

arr = np.array([10, 20, 30, 40, 50])

print(arr)
print("Shape:", arr.shape)
print("Mean:", np.mean(arr))
print("Standard Deviation:", np.std(arr))
# Out:
# [10 20 30 40 50]
# Shape: (5,)
# Mean: 30.0
# Standard Deviation: 14.142135623730951

# %%
# Matrix operations

matrix = np.array([
    [1, 2, 3],
    [4, 5, 6]
])

print(matrix)

print("Transpose:")
print(matrix.T)
# Out:
# [[1 2 3]
#  [4 5 6]]
# Transpose:
# [[1 4]
#  [2 5]
#  [3 6]]

# %%
# 5 students × 3 subjects (Math, Science, English)
marks = np.array([
    [78, 82, 85],
    [91, 89, 94],
    [67, 72, 70],
    [88, 90, 86],
    [56, 60, 58]
])

student_names = ["Aarav", "Diya", "Rohan", "Ananya", "Kabir"]
subject_names = ["Math", "Science", "English"]

print("Marks Array:")
print(marks)
# Out:
# Marks Array:
# [[78 82 85]
#  [91 89 94]
#  [67 72 70]
#  [88 90 86]
#  [56 60 58]]

# %% [markdown]
# ### Numpy performance - Student Performance Analytics
# Write the code with reference to the marks array defined above
# 1. Print:
#
#    a) Shape of the array
#
#    b) Number of dimensions
#
#    c) Data type
# 2. Calculate:
#
#    a) Total marks of each student
#
#    b) Average marks of each student
#
# 3. Find:
#
#    a) Highest marks in each subject
#
#    b) Lowest marks in each subject
#
# 4. Add 5 grace marks to every student using broadcasting.
# 5. Replace all marks below 70 with 0.
# 6. Find the topper (student with highest total marks).
# 7. Create a new array containing students whose average marks are above 80.
# 8. Count how many marks are greater than 85.

# %%
print(marks.shape)
print(marks.ndim)
print(marks.dtype)
# Out:
# (5, 3)
# 2
# int64

# %%
Totalmarks=np.sum(marks,axis=1)
print(Totalmarks)
Averagemarks=np.mean(marks,axis=1)
print(Averagemarks)
# Out:
# [245 274 209 264 174]
# [81.66666667 91.33333333 69.66666667 88.         58.        ]

# %%
highestmarks=np.max(marks,axis=0)
print(highestmarks)
lowestmarks=np.min(marks,axis=0)
print(lowestmarks)
# Out:
# [91 90 94]
# [56 60 58]

# %%
marks+=5
print(marks)
# Out:
# [[83 87 90]
#  [96 94 99]
#  [72 77 75]
#  [93 95 91]
#  [61 65 63]]

# %%
marks[marks<70]=0
print(marks)
# Out:
# [[83 87 90]
#  [96 94 99]
#  [72 77 75]
#  [93 95 91]
#  [ 0  0  0]]

# %%
topper=np.argmax(Totalmarks)
print(student_names[topper])
# Out:
# Diya

# %%
topstudents=np.array(student_names)[Averagemarks > 80]
print(topstudents)
# Out:
# ['Aarav' 'Diya' 'Ananya']

# %%
count=np.sum(marks>85)
print(count)
# Out:
# 8

# %% [markdown]
# # 2. Pandas and CSV Files
#
# CSV (Comma Separated Values) files are commonly used in data analysis.
#
# We will now load a CSV dataset using Pandas.

# %%
# Reading CSV file

df = pd.read_csv("student_performance_dataset!.csv")

df.head()
# Out:
#   Student_ID    Name  Gender  Math  Science  English  Attendance  Study_Hours  \
# 0       S001   Aarav    Male    78       82       85          92            3
# 1       S002    Diya  Female    91       89       94          96            5
# 2       S003   Rohan    Male    67       72       70          80            2
# 3       S004  Ananya  Female    88       90       86          95            4
# 4       S005   Kabir    Male    56       60       58          68            1
#
#    Sports_Score Grade
# 0            70     B
# 1            65     A
# 2            88     C
# 3            75     A
# 4            92     D

# %%
# Reading CSV file

df = pd.read_csv("student_performance_dataset!.csv")

df.head()
# Out:
#   Student_ID    Name  Gender  Math  Science  English  Attendance  Study_Hours  \
# 0       S001   Aarav    Male    78       82       85          92            3
# 1       S002    Diya  Female    91       89       94          96            5
# 2       S003   Rohan    Male    67       72       70          80            2
# 3       S004  Ananya  Female    88       90       86          95            4
# 4       S005   Kabir    Male    56       60       58          68            1
#
#    Sports_Score Grade
# 0            70     B
# 1            65     A
# 2            88     C
# 3            75     A
# 4            92     D

# %%
# Dataset information

print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student_ID    20 non-null     str
#  1   Name          20 non-null     str
#  2   Gender        20 non-null     str
#  3   Math          20 non-null     int64
#  4   Science       20 non-null     int64
#  5   English       20 non-null     int64
#  6   Attendance    20 non-null     int64
#  7   Study_Hours   20 non-null     int64
#  8   Sports_Score  20 non-null     int64
#  9   Grade         20 non-null     str
# dtypes: int64(6), str(4)
# memory usage: 1.7 KB
# None

# %%
# Statistical summary

df.describe()
# Out:
#            Math    Science    English  Attendance  Study_Hours  Sports_Score
# count  20.00000  20.000000  20.000000   20.000000    20.000000     20.000000
# mean   77.90000  80.750000  81.450000   87.300000     3.550000     75.950000
# std    12.19534  11.760214  11.505033   10.402935     1.605091     10.313379
# min    56.00000  60.000000  58.000000   68.000000     1.000000     60.000000
# 25%    68.50000  71.750000  72.250000   79.500000     2.000000     68.250000
# 50%    79.50000  83.000000  83.500000   91.000000     3.500000     74.000000
# 75%    88.25000  90.250000  90.500000   96.000000     5.000000     85.500000
# max    95.00000  98.000000  97.000000   99.000000     6.000000     92.000000

# %%
# Adding a new column

df["Average"] = (
    df["Math"] +
    df["Science"] +
    df["English"]
) / 3

df.head()
# Out:
#   Student_ID    Name  Gender  Math  Science  English  Attendance  Study_Hours  \
# 0       S001   Aarav    Male    78       82       85          92            3
# 1       S002    Diya  Female    91       89       94          96            5
# 2       S003   Rohan    Male    67       72       70          80            2
# 3       S004  Ananya  Female    88       90       86          95            4
# 4       S005   Kabir    Male    56       60       58          68            1
#
#    Sports_Score Grade    Average
# 0            70     B  81.666667
# 1            65     A  91.333333
# 2            88     C  69.666667
# 3            75     A  88.000000
# 4            92     D  58.000000

# %%
# Filtering students with high average

high_average = df[df["Average"] > 85]

high_average
# Out:
#    Student_ID    Name  Gender  Math  Science  English  Attendance  \
# 1        S002    Diya  Female    91       89       94          96
# 3        S004  Ananya  Female    88       90       86          95
# 5        S006   Meera  Female    95       98       97          99
# 7        S008    Isha  Female    84       88       90          93
# 9        S010  Saanvi  Female    89       91       93          97
# 11       S012   Kiara  Female    93       95       96          98
# 15       S016   Aditi  Female    87       92       89          96
# 17       S018   Navya  Female    90       94       92          99
# 19       S020  Ritika  Female    85       86       88          94
#
#     Study_Hours  Sports_Score Grade    Average
# 1             5            65     A  91.333333
# 3             4            75     A  88.000000
# 5             6            60     A  96.666667
# 7             4            72     A  87.333333
# 9             5            66     A  91.000000
# 11            6            64     A  94.666667
# 15            5            69     A  89.333333
# 17            6            62     A  92.000000
# 19            4            71     B  86.333333

# %% [markdown]
# ### Tasks
# Tasks
#
# 1. Display:
#
#     a) First 5 rows
#
#     b) Last 5 rows
#
#     c) Column names
#
#     d) Dataset information
#
# 2. Find:
#
#     a) Average marks in Math
#
#     b) Average marks in Science
#
#     c) Average marks in English
#
#     d) Display students:
#
#     e) Who scored more than 80 in Math
#
#     f) Who scored more than 75 in all subjects
#
# 3. Create a new column: Total_Marks containing total marks of all subjects.
#
# 4. Create another column: Average_Marks containing average marks.
#
# 5. Find:
#
#     a) Student with highest total marks
#
#     b) Student with lowest total marks
#
#     c) Sort the dataframe by:
#
#     d) Total_Marks in descending order
#
# 6. Count:
#
#     a) Number of male and female students
#
#     b) Number of students in each grade
#
#     c) Filter students whose attendance is below 75%.
#
#     d) Save the updated dataframe as: updated_student_performance.csv

# %%
print(df.head())
print(df.tail())
print(df.columns)
print(df.info)
# Out:
#   Student_ID    Name  Gender  Math  Science  English  Attendance  Study_Hours  \
# 0       S001   Aarav    Male    78       82       85          92            3
# 1       S002    Diya  Female    91       89       94          96            5
# 2       S003   Rohan    Male    67       72       70          80            2
# 3       S004  Ananya  Female    88       90       86          95            4
# 4       S005   Kabir    Male    56       60       58          68            1
#
#    Sports_Score Grade    Average
# 0            70     B  81.666667
# 1            65     A  91.333333
# 2            88     C  69.666667
# 3            75     A  88.000000
# 4            92     D  58.000000
#    Student_ID    Name  Gender  Math  Science  English  Attendance  \
# 15       S016   Aditi  Female    87       92       89          96
# 16       S017   Krish    Male    72       74       75          82
# 17       S018   Navya  Female    90       94       92          99
# 18       S019    Yash    Male    64       68       70          72
# 19       S020  Ritika  Female    85       86       88          94
#
#     Study_Hours  Sports_Score Grade    Average
# 15            5            69     A  89.333333
# 16            3            80     B  73.666667
# 17            6            62     A  92.000000
# 18            2            87     C  67.333333
# 19            4            71     B  86.333333
# Index(['Student_ID', 'Name', 'Gender', 'Math', 'Science', 'English',
#        'Attendance', 'Study_Hours', 'Sports_Score', 'Grade', 'Average'],
#       dtype='str')
# <bound method DataFrame.info of    Student_ID     Name  Gender  Math  Science  English  Attendance  \
# 0        S001    Aarav    Male    78       82       85          92
# 1        S002     Diya  Female    91       89       94          96
# 2        S003    Rohan    Male    67       72       70          80
# 3        S004   Ananya  Female    88       90       86          95
# 4        S005    Kabir    Male    56       60       58          68
# 5        S006    Meera  Female    95       98       97          99
# 6        S007    Arjun    Male    73       76       79          85
# 7        S008     Isha  Female    84       88       90          93
# 8        S009   Vivaan    Male    62       65       68          74
# 9        S010   Saanvi  Female    89       91       93          97
# 10       S011   Aditya    Male    76       79       81          88
# 11       S012    Kiara  Female    93       95       96          98
# 12       S013  Reyansh    Male    58       61       63          70
# 13       S014     Mira  Female    81       84       82          90
# 14       S015    Dhruv    Male    69       71       73          78
# 15       S016    Aditi  Female    87       92       89          96
# 16       S017    Krish    Male    72       74       75          82
# 17       S018    Navya  Female    90       94       92          99
# 18       S019     Yash    Male    64       68       70          72
# 19       S020   Ritika  Female    85       86       88          94
#
#     Study_Hours  Sports_Score Grade    Average
# 0             3            70     B  81.666667
# 1             5            65     A  91.333333
# 2             2            88     C  69.666667
# 3             4            75     A  88.000000
# 4             1            92     D  58.000000
# 5             6            60     A  96.666667
# 6             3            81     B  76.000000
# 7             4            72     A  87.333333
# 8             2            90     C  65.000000
# 9             5            66     A  91.000000
# 10            3            78     B  78.666667
# 11            6            64     A  94.666667
# 12            1            91     D  60.666667
# 13            4            73     B  82.333333
# 14            2            85     C  71.000000
# 15            5            69     A  89.333333
# 16            3            80     B  73.666667
# 17            6            62     A  92.000000
# 18            2            87     C  67.333333
# 19            4            71     B  86.333333  >

# %%
print(df['Math'].mean())
print(df['Science'].mean())
print(df['English'].mean())
print(df[df['Math']>80])
print(df[(df['Math']>75)&(df['Science']>75)&(df['English']>75)])
# Out:
# 77.9
# 80.75
# 81.45
#    Student_ID    Name  Gender  Math  Science  English  Attendance  \
# 1        S002    Diya  Female    91       89       94          96
# 3        S004  Ananya  Female    88       90       86          95
# 5        S006   Meera  Female    95       98       97          99
# 7        S008    Isha  Female    84       88       90          93
# 9        S010  Saanvi  Female    89       91       93          97
# 11       S012   Kiara  Female    93       95       96          98
# 13       S014    Mira  Female    81       84       82          90
# 15       S016   Aditi  Female    87       92       89          96
# 17       S018   Navya  Female    90       94       92          99
# 19       S020  Ritika  Female    85       86       88          94
#
#     Study_Hours  Sports_Score Grade    Average
# 1             5            65     A  91.333333
# 3             4            75     A  88.000000
# 5             6            60     A  96.666667
# 7             4            72     A  87.333333
# 9             5            66     A  91.000000
# 11            6            64     A  94.666667
# 13            4            73     B  82.333333
# 15            5            69     A  89.333333
# 17            6            62     A  92.000000
# 19            4            71     B  86.333333
#    Student_ID    Name  Gender  Math  Science  English  Attendance  \
# 0        S001   Aarav    Male    78       82       85          92
# 1        S002    Diya  Female    91       89       94          96
# 3        S004  Ananya  Female    88       90       86          95
# 5        S006   Meera  Female    95       98       97          99
# 7        S008    Isha  Female    84       88       90          93
# 9        S010  Saanvi  Female    89       91       93          97
# 10       S011  Aditya    Male    76       79       81          88
# 11       S012   Kiara  Female    93       95       96          98
# 13       S014    Mira  Female    81       84       82          90
# 15       S016   Aditi  Female    87       92       89          96
# 17       S018   Navya  Female    90       94       92          99
# 19       S020  Ritika  Female    85       86       88          94
#
#     Study_Hours  Sports_Score Grade    Average
# 0             3            70     B  81.666667
# 1             5            65     A  91.333333
# 3             4            75     A  88.000000
# 5             6            60     A  96.666667
# 7             4            72     A  87.333333
# 9             5            66     A  91.000000
# 10            3            78     B  78.666667
# 11            6            64     A  94.666667
# 13            4            73     B  82.333333
# 15            5            69     A  89.333333
# 17            6            62     A  92.000000
# 19            4            71     B  86.333333

# %%
df['Total_Marks']=df[['Math','Science','English']].sum(axis=1)

# %%
df['Average_Marks']=df[['Math','Science','English']].mean(axis=1)

# %%
max_marks=df["Total_Marks"].max()
print(df[df["Total_Marks"]==max_marks])
# Out:
#   Student_ID   Name  Gender  Math  Science  English  Attendance  Study_Hours  \
# 5       S006  Meera  Female    95       98       97          99            6
#
#    Sports_Score Grade    Average  Total_Marks  Average_Marks
# 5            60     A  96.666667          290      96.666667

# %%
min_marks=df["Total_Marks"].min()
print(df[df["Total_Marks"]==min_marks])
# Out:
#   Student_ID   Name Gender  Math  Science  English  Attendance  Study_Hours  \
# 4       S005  Kabir   Male    56       60       58          68            1
#
#    Sports_Score Grade  Average  Total_Marks  Average_Marks
# 4            92     D     58.0          174           58.0

# %%
df=df.sort_values(by="Total_Marks",ascending=False)

# %%
Malecount=(df['Gender']=='Male').sum()
print(Malecount)
Femalecount=(df['Gender']=='Female').sum()
print(Femalecount)
low_attendance_students=df[df["Attendance"]<75]
print(low_attendance_students)
df.to_csv("updated_student_performance.csv",index=False)
# Out:
# 10
# 10
#    Student_ID     Name Gender  Math  Science  English  Attendance  \
# 18       S019     Yash   Male    64       68       70          72
# 8        S009   Vivaan   Male    62       65       68          74
# 12       S013  Reyansh   Male    58       61       63          70
# 4        S005    Kabir   Male    56       60       58          68
#
#     Study_Hours  Sports_Score Grade    Average  Total_Marks  Average_Marks
# 18            2            87     C  67.333333          202      67.333333
# 8             2            90     C  65.000000          195      65.000000
# 12            1            91     D  60.666667          182      60.666667
# 4             1            92     D  58.000000          174      58.000000

# %% [markdown]
# # 3. Matplotlib Basics
#
# Matplotlib is used for plotting and visualizing data.

# %%
# Note: Make sure you have completed the Pandas section above
# so that the Total_Marks column exists in the dataframe.
# Line plot of student averages

plt.figure(figsize=(8, 5))

plt.plot(df["Name"], df["Average"], marker='o')

plt.title("Student Average Scores")
plt.xlabel("Student Name")
plt.ylabel("Average Score")

plt.xticks(rotation=45)
plt.grid(True)

plt.show()

# %%
# Bar chart

subject_means = [
    df["Math"].mean(),
    df["Science"].mean(),
    df["English"].mean()
]

subjects = ["Math", "Science", "English"]

plt.bar(subjects, subject_means)

plt.title("Average Marks by Subject")
plt.ylabel("Average Marks")

plt.show()

# %%
# Histogram

all_marks = pd.concat([
    df["Math"],
    df["Science"],
    df["English"]
])

plt.hist(all_marks, bins=10)

plt.title("Distribution of Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ### Tasks
#
# Use the same CSV file.
#
# 1. Create a line plot showing marks of the first 10 students in Math.
#
# 2. Create a bar chart comparing average marks of:
#
# Math
# Science
# English
#
# 3. Create a pie chart showing distribution of grades.
#
# 4. Create a histogram for attendance percentage.
#
# 5. Create a scatter plot between:
#
# Attendance
# Total_Mark
#
# 6. Create 2 subplots in the same figure:
#
# Math marks line chart
# Grade distribution bar chart
#
# 7. Customize any graph using:
#
# Figure size
# Line style
# Marker style
# Legend
# Grid
#
# Save any one graph as: student_performance_chart.png

# %%
plt.figure(figsize=(8,5))
plt.plot(df['Name'].head(10),df["Math"].head(10))
plt.title("Maths Marks of First 10 Students")
plt.xlabel("Students")
plt.ylabel("Maths Marks")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.bar(['Math','Science','English'],[df['Math'].mean(),df['Science'].mean(),df['English'].mean()])
plt.title("Average Marks in Subjects")
plt.xlabel("Subjects")
plt.ylabel("Average Marks")
plt.show()

# %%
plt.figure(figsize=(6,6))
grades=df["Grade"].value_counts()
plt.pie(grades,labels=grades.index)
plt.savefig('student_performance_chart.png')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Attendance"])
plt.title("Attendance Percentage")
plt.xlabel("Attendance")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df["Attendance"],df["Total_Marks"])
plt.title("Attendance vs Total Marks")
plt.xlabel("Attendance")
plt.ylabel("Total Marks")
plt.show()

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(df["Name"].head(10),df["Math"].head(10),marker="o")
plt.title("Math Marks")

plt.subplot(1,2,2)
grades = df["Grade"].value_counts()
plt.bar(grades.index, grades.values)
plt.title("Grade Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(df["Name"].head(10),df["Math"].head(10),marker="o")
plt.title("Math Marks of First 10 Students")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.grid(True)
plt.show()

# %% [markdown]
# # # 4. Final Assignment — CSV Based Analysis Project
#
# Use the file:
#
# `final_assignment_dataset.csv`
#
# ---
#
# ## Tasks
#
# ### Part 1 — Load Dataset
# 1. Read the CSV file using Pandas.
# 2. Display:
#    - First 5 rows
#    - Dataset information
#    - Statistical summary
#
# ---
#
# ### Part 2 — Data Processing
# 1. Create:
#    - Total Marks
#    - Average Marks
# 2. Find:
#    - Highest scoring student
#    - Lowest scoring student
#    - Students scoring above 80 average
#
# ---
#
# ### Part 3 — NumPy Usage
# Convert the subject columns into NumPy arrays and:
# 1. Find:
#    - Mean
#    - Median
#    - Standard deviation
# 2. Find the subject with highest average marks.
#
# ---
#
# ### Part 4 — Data Visualization
# Create:
# 1. Line plot of student averages
# 2. Histogram of marks
# 3. Bar chart of subject-wise averages
#
# ---
#
# ---
#
# ## Submission
# - Complete all tasks.
# - Add comments where necessary.
# - Submit the completed notebook.

# %%
#Part 1
df=pd.read_csv("final_assignment_dataset.csv")
print(df.head())
print(df.info())
print(df.describe())
# Out:
#   Student_ID   Name  Gender  Math  Science  English  Attendance  Study_Hours  \
# 0       S001  Aryan    Male    90       57       51          77            2
# 1       S002  Priya  Female    58       97       56          94            1
# 2       S003  Karan    Male    77       52       51          65            2
# 3       S004  Sneha  Female    82       88       51          95            2
# 4       S005  Rahul    Male    91       94       84          86            2
#
#    Sports_Score Grade
# 0            64     C
# 1            87     C
# 2            64     C
# 3            95     C
# 4            78     B
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student_ID    30 non-null     str
#  1   Name          30 non-null     str
#  2   Gender        30 non-null     str
#  3   Math          30 non-null     int64
#  4   Science       30 non-null     int64
#  5   English       30 non-null     int64
#  6   Attendance    30 non-null     int64
#  7   Study_Hours   30 non-null     int64
#  8   Sports_Score  30 non-null     int64
#  9   Grade         30 non-null     str
# dtypes: int64(6), str(4)
# memory usage: 2.5 KB
# None
#             Math    Science    English  Attendance  Study_Hours  Sports_Score
# count  30.000000  30.000000  30.000000   30.000000    30.000000      30.00000
# mean   73.766667  76.500000  72.833333   77.566667     3.600000      77.40000
# std    14.138925  14.623434  16.515580   12.039256     2.027399      13.42052
# min    50.000000  52.000000  50.000000   60.000000     1.000000      52.00000
# 25%    60.000000  67.000000  60.000000   67.250000     2.000000      67.25000
# 50%    74.000000  73.500000  69.500000   74.000000     3.000000      78.50000
# 75%    86.500000  91.000000  85.750000   89.000000     5.750000      89.25000
# max    98.000000  99.000000  99.000000   98.000000     7.000000      97.00000

# %%
#Part 2
df['Total_Marks']=df[['Math','Science','English']].sum(axis=1)
df['Average_Marks']=df[['Math','Science','English']].mean(axis=1)

Highest_marks=df["Total_Marks"].max()
print(df[df["Total_Marks"]==Highest_marks])

Lowest_marks=df["Total_Marks"].min()
print(df[df["Total_Marks"]==Lowest_marks])

Marks_above_80=df[df["Average_Marks"]>80]
print(Marks_above_80)
# Out:
#    Student_ID   Name Gender  Math  Science  English  Attendance  Study_Hours  \
# 14       S015  Rohit   Male    94       93       91          64            5
#
#     Sports_Score Grade  Total_Marks  Average_Marks
# 14            90     A          278      92.666667
#   Student_ID   Name Gender  Math  Science  English  Attendance  Study_Hours  \
# 2       S003  Karan   Male    77       52       51          65            2
#
#    Sports_Score Grade  Total_Marks  Average_Marks
# 2            64     C          180           60.0
#    Student_ID    Name  Gender  Math  Science  English  Attendance  \
# 4        S005   Rahul    Male    91       94       84          86
# 10       S011  Suresh    Male    89       73       86          72
# 14       S015   Rohit    Male    94       93       91          64
# 17       S018   Swati  Female    70       99       99          63
# 25       S026    Neha  Female    74       88       79          93
# 27       S028  Simran  Female    98       67       99          81
# 29       S030   Payal  Female    66       82       98          71
#
#     Study_Hours  Sports_Score Grade  Total_Marks  Average_Marks
# 4             2            78     B          269      89.666667
# 10            6            54     B          248      82.666667
# 14            5            90     A          278      92.666667
# 17            2            52     B          268      89.333333
# 25            3            85     B          241      80.333333
# 27            1            68     B          264      88.000000
# 29            5            56     B          246      82.000000

# %%
#Part 3
arr=np.array(df[['Math','Science','English']])
Subjects=['Math','Science','English']
Mean=np.mean(arr)
Median=np.median(arr)
Standard_Deviation=np.std(arr)
print(Mean,Median,Standard_Deviation)

math_avg=np.mean(df["Math"])
science_avg=np.mean(df["Science"])
english_avg=np.mean(df["English"])
highest_avg=max(math_avg, science_avg, english_avg)
if (highest_avg==math_avg):
    print("Highest Average Marks Subject:Math")
elif (highest_avg==science_avg):
    print("Highest Average Marks Subject:Science")
else:
    print("Highest Average Marks Subject:English")
# Out:
# 74.36666666666666 74.0 14.954337906514692
# Highest Average Marks Subject:Science

# %%
#Part 4

plt.figure(figsize=(10,10))
plt.plot(df['Average_Marks'], marker='o')
plt.title("Student Averages")
plt.xlabel("Student")
plt.ylabel("Average")
plt.grid(True)

plt.figure(figsize=(8,5))
plt.hist(df["Total_Marks"])
plt.title("Distribution of Total Marks")
plt.xlabel("Total Marks")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(6,4))
plt.bar(["Math", "Science", "English"],[df["Math"].mean(),df["Science"].mean(),df["English"].mean()])
plt.title("Subject-wise Average Marks")
plt.xlabel("Subjects")
plt.ylabel("Average Marks")
plt.show()
